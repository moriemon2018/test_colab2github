# %% [markdown]
# <a href="https://colab.research.google.com/github/moriemon2018/test_colab2github/blob/master/test_save_colab2github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colaboratory の「GitHub にコピーを保存」機能の挙動を確認するためのノートブック。

# %%
print("Hello Colaboratory and GitHub!")
# Out:
# Hello Colaboratory and GitHub!
